# %% [markdown]
# # TensorFlow Classification

# %% [markdown]
# ## Data
#
# https://archive.ics.uci.edu/ml/datasets/pima+indians+diabetes
#
# 1. Title: Pima Indians Diabetes Database
#
# 2. Sources:
#    (a) Original owners: National Institute of Diabetes and Digestive and
#                         Kidney Diseases
#    (b) Donor of database: Vincent Sigillito (vgs@aplcen.apl.jhu.edu)
#                           Research Center, RMI Group Leader
#                           Applied Physics Laboratory
#                           The Johns Hopkins University
#                           Johns Hopkins Road
#                           Laurel, MD 20707
#                           (301) 953-6231
#    (c) Date received: 9 May 1990
#
# 3. Past Usage:
#     1. Smith,~J.~W., Everhart,~J.~E., Dickson,~W.~C., Knowler,~W.~C., \&
#        Johannes,~R.~S. (1988). Using the ADAP learning algorithm to forecast
#        the onset of diabetes mellitus.  In {\it Proceedings of the Symposium
#        on Computer Applications and Medical Care} (pp. 261--265).  IEEE
#        Computer Society Press.
#
#        The diagnostic, binary-valued variable investigated is whether the
#        patient shows signs of diabetes according to World Health Organization
#        criteria (i.e., if the 2 hour post-load plasma glucose was at least
#        200 mg/dl at any survey  examination or if found during routine medical
#        care).   The population lives near Phoenix, Arizona, USA.
#
#        Results: Their ADAP algorithm makes a real-valued prediction between
#        0 and 1.  This was transformed into a binary decision using a cutoff of
#        0.448.  Using 576 training instances, the sensitivity and specificity
#        of their algorithm was 76% on the remaining 192 instances.
#
# 4. Relevant Information:
#       Several constraints were placed on the selection of these instances from
#       a larger database.  In particular, all patients here are females at
#       least 21 years old of Pima Indian heritage.  ADAP is an adaptive learning
#       routine that generates and executes digital analogs of perceptron-like
#       devices.  It is a unique algorithm; see the paper for details.
#
# 5. Number of Instances: 768
#
# 6. Number of Attributes: 8 plus class
#
#     7. For Each Attribute: (all numeric-valued)
#        1. Number of times pregnant
#        2. Plasma glucose concentration a 2 hours in an oral glucose tolerance test
#        3. Diastolic blood pressure (mm Hg)
#        4. Triceps skin fold thickness (mm)
#        5. 2-Hour serum insulin (mu U/ml)
#        6. Body mass index (weight in kg/(height in m)^2)
#        7. Diabetes pedigree function
#        8. Age (years)
#        9. Class variable (0 or 1)
#
# 8. Missing Attribute Values: Yes
#
# 9. Class Distribution: (class value 1 is interpreted as "tested positive for
#    diabetes")
#
#    Class Value  Number of instances
#    0            500
#    1            268
#
# 10. Brief statistical analysis:
#
#         Attribute number:    Mean:   Standard Deviation:
#         1.                     3.8     3.4
#         2.                   120.9    32.0
#         3.                    69.1    19.4
#         4.                    20.5    16.0
#         5.                    79.8   115.2
#         6.                    32.0     7.9
#         7.                     0.5     0.3
#         8.                    33.2    11.8

# %%
import pandas as pd

# %%
diabetes = pd.read_csv('pima-indians-diabetes.csv')

# %%
diabetes.head()
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure   Triceps   Insulin  \
# 0                6               0.743719        0.590164  0.353535  0.000000
# 1                1               0.427136        0.540984  0.292929  0.000000
# 2                8               0.919598        0.524590  0.000000  0.000000
# 3                1               0.447236        0.540984  0.232323  0.111111
# 4                0               0.688442        0.327869  0.353535  0.198582
#
#         BMI  Pedigree  Age  Class Group
# 0  0.500745  0.234415   50      1     B
# 1  0.396423  0.116567   31      0     C
# 2  0.347243  0.253629   32      1     B
# 3  0.418778  0.038002   21      0     B
# 4  0.642325  0.943638   33      1     C

# %%
diabetes.dtypes
# Out:
# Number_pregnant            int64
# Glucose_concentration    float64
# Blood_pressure           float64
# Triceps                  float64
# Insulin                  float64
# BMI                      float64
# Pedigree                 float64
# Age                        int64
# Class                      int64
# Group                     object
# dtype: object

# %%
diabetes.columns
# Out:
# Index(['Number_pregnant', 'Glucose_concentration', 'Blood_pressure', 'Triceps',
#        'Insulin', 'BMI', 'Pedigree', 'Age', 'Class', 'Group'],
#       dtype='object')

# %% [markdown]
# ### Clean the Data

# %%
cols_to_norm = ['Number_pregnant', 'Glucose_concentration', 'Blood_pressure', 'Triceps',
       'Insulin', 'BMI', 'Pedigree']

# %%
diabetes[cols_to_norm] = diabetes[cols_to_norm].apply(lambda x: (x - x.min()) / (x.max() - x.min()))

# %%
diabetes.head()
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure   Triceps   Insulin  \
# 0         0.352941               0.743719        0.590164  0.353535  0.000000
# 1         0.058824               0.427136        0.540984  0.292929  0.000000
# 2         0.470588               0.919598        0.524590  0.000000  0.000000
# 3         0.058824               0.447236        0.540984  0.232323  0.111111
# 4         0.000000               0.688442        0.327869  0.353535  0.198582
#
#         BMI  Pedigree  Age  Class Group
# 0  0.500745  0.234415   50      1     B
# 1  0.396423  0.116567   31      0     C
# 2  0.347243  0.253629   32      1     B
# 3  0.418778  0.038002   21      0     B
# 4  0.642325  0.943638   33      1     C

# %% [markdown]
# ### Feature Columns

# %%
diabetes.columns
# Out:
# Index(['Number_pregnant', 'Glucose_concentration', 'Blood_pressure', 'Triceps',
#        'Insulin', 'BMI', 'Pedigree', 'Age', 'Class', 'Group'],
#       dtype='object')

# %%
import tensorflow as tf

# %%
gpu_options = tf.GPUOptions(per_process_gpu_memory_fraction=0.4)  
sess = tf.Session(config=tf.ConfigProto(gpu_options=gpu_options))

# %% [markdown]
# ### Continuous Features
#
# * Number of times pregnant
# * Plasma glucose concentration a 2 hours in an oral glucose tolerance test
# * Diastolic blood pressure (mm Hg)
# * Triceps skin fold thickness (mm)
# * 2-Hour serum insulin (mu U/ml)
# * Body mass index (weight in kg/(height in m)^2)
# * Diabetes pedigree function

# %%
num_preg = tf.feature_column.numeric_column('Number_pregnant')
plasma_gluc = tf.feature_column.numeric_column('Glucose_concentration')
dias_press = tf.feature_column.numeric_column('Blood_pressure')
tricep = tf.feature_column.numeric_column('Triceps')
insulin = tf.feature_column.numeric_column('Insulin')
bmi = tf.feature_column.numeric_column('BMI')
diabetes_pedigree = tf.feature_column.numeric_column('Pedigree')
age = tf.feature_column.numeric_column('Age')

# %% [markdown]
# ### Categorical Features

# %% [markdown]
# If you know the set of all possible feature values of a column and there are only a few of them, you can use categorical_column_with_vocabulary_list. If you don't know the set of possible values in advance you can use categorical_column_with_hash_bucket

# %%
assigned_group = tf.feature_column.categorical_column_with_vocabulary_list('Group',['A','B','C','D'])
# Alternative
# assigned_group = tf.feature_column.categorical_column_with_hash_bucket('Group', hash_bucket_size=10)

# %% [markdown]
# ### Converting Continuous to Categorical

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
diabetes['Age'].hist(bins=20)

# %%
age_buckets = tf.feature_column.bucketized_column(age, boundaries=[20,30,40,50,60,70,80])

# %% [markdown]
# ### Putting them together

# %%
feat_cols = [num_preg ,plasma_gluc,dias_press ,tricep ,insulin,bmi,diabetes_pedigree ,assigned_group, age_buckets]

# %% [markdown]
# ### Train Test Split

# %%
diabetes.head()
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure   Triceps   Insulin  \
# 0         0.352941               0.743719        0.590164  0.353535  0.000000
# 1         0.058824               0.427136        0.540984  0.292929  0.000000
# 2         0.470588               0.919598        0.524590  0.000000  0.000000
# 3         0.058824               0.447236        0.540984  0.232323  0.111111
# 4         0.000000               0.688442        0.327869  0.353535  0.198582
#
#         BMI  Pedigree  Age  Class Group
# 0  0.500745  0.234415   50      1     B
# 1  0.396423  0.116567   31      0     C
# 2  0.347243  0.253629   32      1     B
# 3  0.418778  0.038002   21      0     B
# 4  0.642325  0.943638   33      1     C

# %%
diabetes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 10 columns):
# Number_pregnant          768 non-null float64
# Glucose_concentration    768 non-null float64
# Blood_pressure           768 non-null float64
# Triceps                  768 non-null float64
# Insulin                  768 non-null float64
# BMI                      768 non-null float64
# Pedigree                 768 non-null float64
# Age                      768 non-null int64
# Class                    768 non-null int64
# Group                    768 non-null object
# dtypes: float64(7), int64(2), object(1)
# memory usage: 60.1+ KB

# %%
x_data = diabetes.drop('Class',axis=1)

# %%
labels = diabetes['Class']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x_data,labels,test_size=0.33, random_state=101)

# %% [markdown]
# ### Input Function

# %%
input_func = tf.estimator.inputs.pandas_input_fn(x=X_train,y=y_train,batch_size=10,num_epochs=1000,shuffle=True)

# %% [markdown]
# ### Creating the Model

# %%
model = tf.estimator.LinearClassifier(feature_columns=feat_cols,n_classes=2)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\USER\AppData\Local\Temp\tmpezt_5c_u
# INFO:tensorflow:Using config: {'_model_dir': 'C:\\Users\\USER\\AppData\\Local\\Temp\\tmpezt_5c_u', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x000001F04C219C08>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
model.train(input_fn=input_func,steps=1000)
# Out:
# WARNING:tensorflow:From c:\users\user\anaconda3\envs\yienv\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From c:\users\user\anaconda3\envs\yienv\lib\site-packages\tensorflow_estimator\python\estimator\inputs\queues\feeding_queue_runner.py:62: QueueRunner.__init__ (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# WARNING:tensorflow:From c:\users\user\anaconda3\envs\yienv\lib\site-packages\tensorflow_estimator\python\estimator\inputs\queues\feeding_functions.py:500: add_queue_runner (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From c:\users\user\anaconda3\envs\yienv\lib\site-packages\tensorflow\python\feature_column\feature_column_v2.py:2703: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From c:\users\user\anaconda3\envs\yienv\lib\site-packages\tensorflow\python\feature_column\feature_column_v2.py:2898: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# WARNING:tensorflow:From c:\users\user\anaconda3\envs\yienv\lib\site-packages\tensorflow\python\training\monitored_session.py:809: start_queue_runners (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# INFO:tensorflow:Saving checkpoints for 0 into C:\Users\USER\AppData\Local\Temp\tmpezt_5c_u\model.ckpt.
# INFO:tensorflow:loss = 6.931472, step = 0
# INFO:tensorflow:global_step/sec: 173.109
# INFO:tensorflow:loss = 5.2513714, step = 100 (0.579 sec)
# INFO:tensorflow:global_step/sec: 258.42
# INFO:tensorflow:loss = 9.269282, step = 200 (0.386 sec)
# INFO:tensorflow:global_step/sec: 259.089
# INFO:tensorflow:loss = 3.613607, step = 300 (0.387 sec)
# INFO:tensorflow:global_step/sec: 264.555
# INFO:tensorflow:loss = 4.9268656, step = 400 (0.377 sec)
# INFO:tensorflow:global_step/sec: 243.959
# INFO:tensorflow:loss = 8.462013, step = 500 (0.410 sec)
# INFO:tensorflow:global_step/sec: 255.121
# INFO:tensorflow:loss = 5.1147366, step = 600 (0.392 sec)
# INFO:tensorflow:global_step/sec: 248.198
# INFO:tensorflow:loss = 4.20855, step = 700 (0.403 sec)
# INFO:tensorflow:global_step/sec: 259.088
# INFO:tensorflow:loss = 6.784052, step = 800 (0.387 sec)
# INFO:tensorflow:global_step/sec: 261.113
# INFO:tensorflow:loss = 5.3938932, step = 900 (0.382 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into C:\Users\USER\AppData\Local\Temp\tmpezt_5c_u\model.ckpt.
# INFO:tensorflow:Loss for final step: 6.440199.

# %%
# Useful link ofr your own data
# https://stackoverflow.com/questions/44664285/what-are-the-contraints-for-tensorflow-scope-names

# %% [markdown]
# ## Evaluation

# %%
eval_input_func = tf.estimator.inputs.pandas_input_fn(
      x=X_test,
      y=y_test,
      batch_size=10,
      num_epochs=1,
      shuffle=False)

# %%
results = model.evaluate(eval_input_func)
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From c:\users\user\anaconda3\envs\yienv\lib\site-packages\tensorflow\python\ops\metrics_impl.py:2002: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2019-12-10T16:08:59Z
# INFO:tensorflow:Graph was finalized.
# WARNING:tensorflow:From c:\users\user\anaconda3\envs\yienv\lib\site-packages\tensorflow\python\training\saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from C:\Users\USER\AppData\Local\Temp\tmpezt_5c_u\model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2019-12-10-16:08:59
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.72440946, accuracy_baseline = 0.65748036, auc = 0.7863927, auc_precision_recall = 0.6260998, average_loss = 0.5328839, global_step = 1000, label/mean = 0.34251967, loss = 5.205866, precision = 0.60240966, prediction/mean = 0.37474778, recall = 0.57471263
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1000: C:\Users\USER\AppData\Local\Temp\tmpezt_5c_u\model.ckpt-1000

# %%
results
# Out:
# {'accuracy': 0.72440946,
#  'accuracy_baseline': 0.65748036,
#  'auc': 0.7863927,
#  'auc_precision_recall': 0.6260998,
#  'average_loss': 0.5328839,
#  'label/mean': 0.34251967,
#  'loss': 5.205866,
#  'precision': 0.60240966,
#  'prediction/mean': 0.37474778,
#  'recall': 0.57471263,
#  'global_step': 1000}

# %% [markdown]
# ## Predictions

# %%
pred_input_func = tf.estimator.inputs.pandas_input_fn(
      x=X_test,
      batch_size=10,
      num_epochs=1,
      shuffle=False)

# %%
# Predictions is a generator! 
predictions = model.predict(pred_input_func)

# %%
list(predictions)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\USER\AppData\Local\Temp\tmpezt_5c_u\model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# [{'logits': array([0.15829766], dtype=float32),
#   'logistic': array([0.53949195], dtype=float32),
#   'probabilities': array([0.460508, 0.539492], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.5995389], dtype=float32),
#   'logistic': array([0.6455508], dtype=float32),
#   'probabilities': array([0.35444918, 0.6455508 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.40260136], dtype=float32),
#   'logistic': array([0.40068752], dtype=float32),
#   'probabilities': array([0.5993125, 0.4006875], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.7732258], dtype=float32),
#   'logistic': array([0.31578174], dtype=float32),
#   'probabilities': array([0.6842183, 0.3157817], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.8193805], dtype=float32),
#   'logistic': array([0.13950822], dtype=float32),
#   'probabilities': array([0.86049175, 0.13950822], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.86370504], dtype=float32),
#   'logistic': array([0.7034341], dtype=float32),
#   'probabilities': array([0.29656586, 0.70343417], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.45410526], dtype=float32),
#   'logistic': array([0.6116148], dtype=float32),
#   'probabilities': array([0.38838515, 0.6116149 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.5830562], dtype=float32),
#   'logistic': array([0.35822967], dtype=float32),
#   'probabilities': array([0.6417703 , 0.35822964], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.1529938], dtype=float32),
#   'logistic': array([0.23994267], dtype=float32),
#   'probabilities': array([0.7600573 , 0.23994265], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.1435722], dtype=float32),
#   'logistic': array([0.24166511], dtype=float32),
#   'probabilities': array([0.7583349, 0.2416651], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.9281912], dtype=float32),
#   'logistic': array([0.12695092], dtype=float32),
#   'probabilities': array([0.8730491, 0.1269509], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.760436], dtype=float32),
#   'logistic': array([0.14673573], dtype=float32),
#   'probabilities': array([0.8532642 , 0.14673573], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.7424129], dtype=float32),
#   'logistic': array([0.32247674], dtype=float32),
#   'probabilities': array([0.67752326, 0.3224767 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.3312279], dtype=float32),
#   'logistic': array([0.5820581], dtype=float32),
#   'probabilities': array([0.4179419 , 0.58205813], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.5701249], dtype=float32),
#   'logistic': array([0.17219856], dtype=float32),
#   'probabilities': array([0.82780135, 0.17219858], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.6757979], dtype=float32),
#   'logistic': array([0.3371998], dtype=float32),
#   'probabilities': array([0.6628002, 0.3371998], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.5036166], dtype=float32),
#   'logistic': array([0.37669116], dtype=float32),
#   'probabilities': array([0.6233089 , 0.37669113], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.9220645], dtype=float32),
#   'logistic': array([0.12763152], dtype=float32),
#   'probabilities': array([0.87236845, 0.12763152], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.4385736], dtype=float32),
#   'logistic': array([0.3920809], dtype=float32),
#   'probabilities': array([0.6079191, 0.3920809], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.868718], dtype=float32),
#   'logistic': array([0.13369012], dtype=float32),
#   'probabilities': array([0.86630994, 0.13369012], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.3158917], dtype=float32),
#   'logistic': array([0.21150261], dtype=float32),
#   'probabilities': array([0.78849745, 0.21150263], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.8521312], dtype=float32),
#   'logistic': array([0.29898602], dtype=float32),
#   'probabilities': array([0.70101404, 0.298986  ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.7248223], dtype=float32),
#   'logistic': array([0.673668], dtype=float32),
#   'probabilities': array([0.32633197, 0.673668  ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.3240182], dtype=float32),
#   'logistic': array([0.21015057], dtype=float32),
#   'probabilities': array([0.78984946, 0.21015054], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.5047967], dtype=float32),
#   'logistic': array([0.18171117], dtype=float32),
#   'probabilities': array([0.8182888, 0.1817112], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([1.2908443], dtype=float32),
#   'logistic': array([0.7842901], dtype=float32),
#   'probabilities': array([0.21570992, 0.7842901 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.514246], dtype=float32),
#   'logistic': array([0.1803104], dtype=float32),
#   'probabilities': array([0.8196896 , 0.18031038], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.78970647], dtype=float32),
#   'logistic': array([0.31223172], dtype=float32),
#   'probabilities': array([0.6877683 , 0.31223166], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-2.189561], dtype=float32),
#   'logistic': array([0.10069185], dtype=float32),
#   'probabilities': array([0.89930815, 0.10069185], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.37887275], dtype=float32),
#   'logistic': array([0.5936012], dtype=float32),
#   'probabilities': array([0.40639877, 0.5936012 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([2.8257594], dtype=float32),
#   'logistic': array([0.9440521], dtype=float32),
#   'probabilities': array([0.05594796, 0.9440521 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.3047859], dtype=float32),
#   'logistic': array([0.42438796], dtype=float32),
#   'probabilities': array([0.57561207, 0.42438793], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.8195735], dtype=float32),
#   'logistic': array([0.3058542], dtype=float32),
#   'probabilities': array([0.69414586, 0.3058542 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.29659295], dtype=float32),
#   'logistic': array([0.5736094], dtype=float32),
#   'probabilities': array([0.4263906, 0.5736095], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.1082995], dtype=float32),
#   'logistic': array([0.24818808], dtype=float32),
#   'probabilities': array([0.751812  , 0.24818805], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.43603027], dtype=float32),
#   'logistic': array([0.3926873], dtype=float32),
#   'probabilities': array([0.60731274, 0.3926873 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.11903405], dtype=float32),
#   'logistic': array([0.5297234], dtype=float32),
#   'probabilities': array([0.47027656, 0.5297234 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.60656106], dtype=float32),
#   'logistic': array([0.64715594], dtype=float32),
#   'probabilities': array([0.35284406, 0.647156  ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([1.152609], dtype=float32),
#   'logistic': array([0.7599871], dtype=float32),
#   'probabilities': array([0.24001284, 0.7599871 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.6698171], dtype=float32),
#   'logistic': array([0.3385378], dtype=float32),
#   'probabilities': array([0.6614622, 0.3385378], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.525527], dtype=float32),
#   'logistic': array([0.17864907], dtype=float32),
#   'probabilities': array([0.82135093, 0.17864908], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.19768643], dtype=float32),
#   'logistic': array([0.5492613], dtype=float32),
#   'probabilities': array([0.4507387, 0.5492613], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.7245395], dtype=float32),
#   'logistic': array([0.15128735], dtype=float32),
#   'probabilities': array([0.8487127 , 0.15128738], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.20489228], dtype=float32),
#   'logistic': array([0.5510446], dtype=float32),
#   'probabilities': array([0.44895536, 0.55104464], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.8147142], dtype=float32),
#   'logistic': array([0.14006934], dtype=float32),
#   'probabilities': array([0.85993063, 0.14006934], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-2.1979024], dtype=float32),
#   'logistic': array([0.09993896], dtype=float32),
#   'probabilities': array([0.900061  , 0.09993901], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.46119773], dtype=float32),
#   'logistic': array([0.61329824], dtype=float32),
#   'probabilities': array([0.38670173, 0.6132983 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.5005921], dtype=float32),
#   'logistic': array([0.18233722], dtype=float32),
#   'probabilities': array([0.8176627 , 0.18233722], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.3200747], dtype=float32),
#   'logistic': array([0.21080586], dtype=float32),
#   'probabilities': array([0.7891941 , 0.21080585], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-2.0496469], dtype=float32),
#   'logistic': array([0.11408808], dtype=float32),
#   'probabilities': array([0.88591194, 0.11408807], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.6328466], dtype=float32),
#   'logistic': array([0.16344076], dtype=float32),
#   'probabilities': array([0.83655924, 0.16344078], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.1029372], dtype=float32),
#   'logistic': array([0.24918994], dtype=float32),
#   'probabilities': array([0.7508101 , 0.24918994], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.1302996], dtype=float32),
#   'logistic': array([0.24410579], dtype=float32),
#   'probabilities': array([0.7558942 , 0.24410582], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.42515457], dtype=float32),
#   'logistic': array([0.395284], dtype=float32),
#   'probabilities': array([0.60471606, 0.39528397], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.8645256], dtype=float32),
#   'logistic': array([0.13417643], dtype=float32),
#   'probabilities': array([0.86582357, 0.13417643], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.3036542], dtype=float32),
#   'logistic': array([0.21355069], dtype=float32),
#   'probabilities': array([0.7864493 , 0.21355066], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.3734094], dtype=float32),
#   'logistic': array([0.20206955], dtype=float32),
#   'probabilities': array([0.7979305 , 0.20206957], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.3237727], dtype=float32),
#   'logistic': array([0.21019128], dtype=float32),
#   'probabilities': array([0.7898087 , 0.21019132], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.03182185], dtype=float32),
#   'logistic': array([0.5079548], dtype=float32),
#   'probabilities': array([0.4920452, 0.5079548], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.6868238], dtype=float32),
#   'logistic': array([0.156194], dtype=float32),
#   'probabilities': array([0.843806  , 0.15619399], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.232494], dtype=float32),
#   'logistic': array([0.22574523], dtype=float32),
#   'probabilities': array([0.7742548 , 0.22574523], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.6410996], dtype=float32),
#   'logistic': array([0.655002], dtype=float32),
#   'probabilities': array([0.34499803, 0.655002  ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.612347], dtype=float32),
#   'logistic': array([0.648476], dtype=float32),
#   'probabilities': array([0.35152403, 0.648476  ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.10554028], dtype=float32),
#   'logistic': array([0.52636063], dtype=float32),
#   'probabilities': array([0.47363943, 0.52636063], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.64951783], dtype=float32),
#   'logistic': array([0.34309822], dtype=float32),
#   'probabilities': array([0.6569018, 0.3430982], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.0583446], dtype=float32),
#   'logistic': array([0.51458204], dtype=float32),
#   'probabilities': array([0.485418  , 0.51458204], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.5469291], dtype=float32),
#   'logistic': array([0.17553025], dtype=float32),
#   'probabilities': array([0.82446975, 0.17553024], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.3987582], dtype=float32),
#   'logistic': array([0.19801325], dtype=float32),
#   'probabilities': array([0.80198675, 0.19801325], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.7058002], dtype=float32),
#   'logistic': array([0.15370923], dtype=float32),
#   'probabilities': array([0.8462907 , 0.15370923], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.9022503], dtype=float32),
#   'logistic': array([0.12985401], dtype=float32),
#   'probabilities': array([0.87014604, 0.129854  ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.47424352], dtype=float32),
#   'logistic': array([0.6163876], dtype=float32),
#   'probabilities': array([0.38361233, 0.61638767], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.1789014], dtype=float32),
#   'logistic': array([0.23524979], dtype=float32),
#   'probabilities': array([0.76475024, 0.23524979], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.21549666], dtype=float32),
#   'logistic': array([0.44633335], dtype=float32),
#   'probabilities': array([0.55366665, 0.44633338], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.3360542], dtype=float32),
#   'logistic': array([0.5832317], dtype=float32),
#   'probabilities': array([0.41676828, 0.58323175], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.8651583], dtype=float32),
#   'logistic': array([0.29626274], dtype=float32),
#   'probabilities': array([0.70373726, 0.29626277], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.71968555], dtype=float32),
#   'logistic': array([0.67253774], dtype=float32),
#   'probabilities': array([0.32746223, 0.67253774], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.9880583], dtype=float32),
#   'logistic': array([0.12046245], dtype=float32),
#   'probabilities': array([0.8795376 , 0.12046243], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.5141597], dtype=float32),
#   'logistic': array([0.62578106], dtype=float32),
#   'probabilities': array([0.37421888, 0.62578106], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.9650285], dtype=float32),
#   'logistic': array([0.12292387], dtype=float32),
#   'probabilities': array([0.87707615, 0.12292388], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.30233312], dtype=float32),
#   'logistic': array([0.57501274], dtype=float32),
#   'probabilities': array([0.42498723, 0.57501274], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.6756996], dtype=float32),
#   'logistic': array([0.3372218], dtype=float32),
#   'probabilities': array([0.66277826, 0.3372218 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.6197169], dtype=float32),
#   'logistic': array([0.1652439], dtype=float32),
#   'probabilities': array([0.8347561 , 0.16524392], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.26887524], dtype=float32),
#   'logistic': array([0.56681675], dtype=float32),
#   'probabilities': array([0.43318325, 0.56681675], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.40240967], dtype=float32),
#   'logistic': array([0.59926647], dtype=float32),
#   'probabilities': array([0.40073353, 0.5992665 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.33091557], dtype=float32),
#   'logistic': array([0.58198214], dtype=float32),
#   'probabilities': array([0.4180179 , 0.58198214], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.6121168], dtype=float32),
#   'logistic': array([0.16629493], dtype=float32),
#   'probabilities': array([0.83370507, 0.16629493], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.56330717], dtype=float32),
#   'logistic': array([0.3627826], dtype=float32),
#   'probabilities': array([0.6372174 , 0.36278263], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.7447836], dtype=float32),
#   'logistic': array([0.14870638], dtype=float32),
#   'probabilities': array([0.8512937 , 0.14870633], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.96258247], dtype=float32),
#   'logistic': array([0.7236386], dtype=float32),
#   'probabilities': array([0.27636144, 0.7236386 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([1.5840648], dtype=float32),
#   'logistic': array([0.82977945], dtype=float32),
#   'probabilities': array([0.17022058, 0.82977945], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.4898455], dtype=float32),
#   'logistic': array([0.62007004], dtype=float32),
#   'probabilities': array([0.37992996, 0.62007004], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.3412654], dtype=float32),
#   'logistic': array([0.20730203], dtype=float32),
#   'probabilities': array([0.79269797, 0.20730205], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.17198318], dtype=float32),
#   'logistic': array([0.45710987], dtype=float32),
#   'probabilities': array([0.54289013, 0.45710987], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.4537319], dtype=float32),
#   'logistic': array([0.38847387], dtype=float32),
#   'probabilities': array([0.6115262 , 0.38847384], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.09797907], dtype=float32),
#   'logistic': array([0.4755248], dtype=float32),
#   'probabilities': array([0.52447516, 0.47552478], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.55284685], dtype=float32),
#   'logistic': array([0.3652042], dtype=float32),
#   'probabilities': array([0.63479584, 0.36520416], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.14813733], dtype=float32),
#   'logistic': array([0.46303326], dtype=float32),
#   'probabilities': array([0.53696674, 0.46303323], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.6720841], dtype=float32),
#   'logistic': array([0.1581465], dtype=float32),
#   'probabilities': array([0.8418535, 0.1581465], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.29509056], dtype=float32),
#   'logistic': array([0.57324195], dtype=float32),
#   'probabilities': array([0.42675808, 0.57324195], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.29485083], dtype=float32),
#   'logistic': array([0.57318324], dtype=float32),
#   'probabilities': array([0.4268167 , 0.57318324], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.1690955], dtype=float32),
#   'logistic': array([0.23701856], dtype=float32),
#   'probabilities': array([0.76298153, 0.23701853], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.5211529], dtype=float32),
#   'logistic': array([0.17929181], dtype=float32),
#   'probabilities': array([0.8207082 , 0.17929184], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.5728503], dtype=float32),
#   'logistic': array([0.17181042], dtype=float32),
#   'probabilities': array([0.82818955, 0.17181043], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.9938768], dtype=float32),
#   'logistic': array([0.27014703], dtype=float32),
#   'probabilities': array([0.72985303, 0.270147  ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.36716187], dtype=float32),
#   'logistic': array([0.409227], dtype=float32),
#   'probabilities': array([0.590773  , 0.40922698], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.8285372], dtype=float32),
#   'logistic': array([0.1384126], dtype=float32),
#   'probabilities': array([0.8615874 , 0.13841262], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.7123276], dtype=float32),
#   'logistic': array([0.32908472], dtype=float32),
#   'probabilities': array([0.67091525, 0.32908472], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.2311436], dtype=float32),
#   'logistic': array([0.22598135], dtype=float32),
#   'probabilities': array([0.7740187 , 0.22598132], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-2.2560887], dtype=float32),
#   'logistic': array([0.09482556], dtype=float32),
#   'probabilities': array([0.90517443, 0.09482555], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.9734639], dtype=float32),
#   'logistic': array([0.12201731], dtype=float32),
#   'probabilities': array([0.8779827 , 0.12201731], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([1.068937], dtype=float32),
#   'logistic': array([0.74439466], dtype=float32),
#   'probabilities': array([0.25560528, 0.7443947 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.5400215], dtype=float32),
#   'logistic': array([0.17653215], dtype=float32),
#   'probabilities': array([0.82346785, 0.17653215], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.8807762], dtype=float32),
#   'logistic': array([0.13229975], dtype=float32),
#   'probabilities': array([0.8677003 , 0.13229975], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.831627], dtype=float32),
#   'logistic': array([0.13804457], dtype=float32),
#   'probabilities': array([0.8619554 , 0.13804455], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.05204844], dtype=float32),
#   'logistic': array([0.5130092], dtype=float32),
#   'probabilities': array([0.48699084, 0.5130092 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.07321268], dtype=float32),
#   'logistic': array([0.481705], dtype=float32),
#   'probabilities': array([0.518295, 0.481705], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.1773671], dtype=float32),
#   'logistic': array([0.23552594], dtype=float32),
#   'probabilities': array([0.7644741 , 0.23552594], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.20774716], dtype=float32),
#   'logistic': array([0.44824922], dtype=float32),
#   'probabilities': array([0.5517508, 0.4482492], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.4906192], dtype=float32),
#   'logistic': array([0.18382882], dtype=float32),
#   'probabilities': array([0.8161712 , 0.18382882], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.2815095], dtype=float32),
#   'logistic': array([0.2172934], dtype=float32),
#   'probabilities': array([0.7827066 , 0.21729337], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.03423357], dtype=float32),
#   'logistic': array([0.49144244], dtype=float32),
#   'probabilities': array([0.50855756, 0.49144244], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.01414561], dtype=float32),
#   'logistic': array([0.50353634], dtype=float32),
#   'probabilities': array([0.49646366, 0.50353634], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.7931639], dtype=float32),
#   'logistic': array([0.14268523], dtype=float32),
#   'probabilities': array([0.85731477, 0.14268525], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.30913216], dtype=float32),
#   'logistic': array([0.4233266], dtype=float32),
#   'probabilities': array([0.57667345, 0.42332658], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.7957158], dtype=float32),
#   'logistic': array([0.6890573], dtype=float32),
#   'probabilities': array([0.3109427 , 0.68905735], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.28616798], dtype=float32),
#   'logistic': array([0.57105774], dtype=float32),
#   'probabilities': array([0.42894226, 0.5710578 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.3079853], dtype=float32),
#   'logistic': array([0.42360657], dtype=float32),
#   'probabilities': array([0.57639337, 0.42360657], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.20600224], dtype=float32),
#   'logistic': array([0.5513192], dtype=float32),
#   'probabilities': array([0.4486808, 0.5513192], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.2366858], dtype=float32),
#   'logistic': array([0.2250134], dtype=float32),
#   'probabilities': array([0.77498657, 0.22501339], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.4219633], dtype=float32),
#   'logistic': array([0.19435398], dtype=float32),
#   'probabilities': array([0.805646  , 0.19435397], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.8584839], dtype=float32),
#   'logistic': array([0.13487983], dtype=float32),
#   'probabilities': array([0.8651201 , 0.13487986], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.0176885], dtype=float32),
#   'logistic': array([0.26547793], dtype=float32),
#   'probabilities': array([0.7345221 , 0.26547787], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.00445557], dtype=float32),
#   'logistic': array([0.4988861], dtype=float32),
#   'probabilities': array([0.50111395, 0.4988861 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.82107043], dtype=float32),
#   'logistic': array([0.6944635], dtype=float32),
#   'probabilities': array([0.30553645, 0.6944635 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.2363338], dtype=float32),
#   'logistic': array([0.22507477], dtype=float32),
#   'probabilities': array([0.77492523, 0.22507477], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.6581151], dtype=float32),
#   'logistic': array([0.16001517], dtype=float32),
#   'probabilities': array([0.8399849 , 0.16001518], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.3216694], dtype=float32),
#   'logistic': array([0.42026895], dtype=float32),
#   'probabilities': array([0.57973105, 0.42026895], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.2105293], dtype=float32),
#   'logistic': array([0.2296074], dtype=float32),
#   'probabilities': array([0.7703926 , 0.22960743], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.7877336], dtype=float32),
#   'logistic': array([0.14335082], dtype=float32),
#   'probabilities': array([0.8566492 , 0.14335082], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.5421185], dtype=float32),
#   'logistic': array([0.17622751], dtype=float32),
#   'probabilities': array([0.8237725 , 0.17622751], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.9703102], dtype=float32),
#   'logistic': array([0.12235555], dtype=float32),
#   'probabilities': array([0.8776444 , 0.12235557], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.46952283], dtype=float32),
#   'logistic': array([0.3847292], dtype=float32),
#   'probabilities': array([0.6152708 , 0.38472918], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([1.2599283], dtype=float32),
#   'logistic': array([0.77901375], dtype=float32),
#   'probabilities': array([0.22098623, 0.77901375], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([1.2399658], dtype=float32),
#   'logistic': array([0.7755581], dtype=float32),
#   'probabilities': array([0.22444193, 0.77555805], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.22762299], dtype=float32),
#   'logistic': array([0.5566613], dtype=float32),
#   'probabilities': array([0.4433387, 0.5566613], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.04485273], dtype=float32),
#   'logistic': array([0.5112113], dtype=float32),
#   'probabilities': array([0.4887887, 0.5112113], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.33131254], dtype=float32),
#   'logistic': array([0.5820787], dtype=float32),
#   'probabilities': array([0.4179213, 0.5820787], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-2.0616007], dtype=float32),
#   'logistic': array([0.11288542], dtype=float32),
#   'probabilities': array([0.8871146 , 0.11288544], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.2328304], dtype=float32),
#   'logistic': array([0.5579461], dtype=float32),
#   'probabilities': array([0.44205394, 0.5579461 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([1.1863161], dtype=float32),
#   'logistic': array([0.7660815], dtype=float32),
#   'probabilities': array([0.23391843, 0.7660815 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.33544672], dtype=float32),
#   'logistic': array([0.41691595], dtype=float32),
#   'probabilities': array([0.5830841 , 0.41691595], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.9941491], dtype=float32),
#   'logistic': array([0.27009335], dtype=float32),
#   'probabilities': array([0.7299067 , 0.27009332], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.53258866], dtype=float32),
#   'logistic': array([0.36991334], dtype=float32),
#   'probabilities': array([0.63008666, 0.3699133 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.34390402], dtype=float32),
#   'logistic': array([0.58513856], dtype=float32),
#   'probabilities': array([0.41486144, 0.58513856], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.177952], dtype=float32),
#   'logistic': array([0.23542061], dtype=float32),
#   'probabilities': array([0.7645794 , 0.23542061], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.67468476], dtype=float32),
#   'logistic': array([0.6625514], dtype=float32),
#   'probabilities': array([0.33744863, 0.6625514 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.30793536], dtype=float32),
#   'logistic': array([0.4236188], dtype=float32),
#   'probabilities': array([0.5763812 , 0.42361876], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.2692747], dtype=float32),
#   'logistic': array([0.43308517], dtype=float32),
#   'probabilities': array([0.5669148 , 0.43308514], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.6487004], dtype=float32),
#   'logistic': array([0.16128469], dtype=float32),
#   'probabilities': array([0.8387154 , 0.16128469], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.4373145], dtype=float32),
#   'logistic': array([0.19196156], dtype=float32),
#   'probabilities': array([0.8080385 , 0.19196156], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.4977223], dtype=float32),
#   'logistic': array([0.18276545], dtype=float32),
#   'probabilities': array([0.8172345 , 0.18276547], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.19900894], dtype=float32),
#   'logistic': array([0.45041132], dtype=float32),
#   'probabilities': array([0.5495887 , 0.45041132], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.7564428], dtype=float32),
#   'logistic': array([0.14723644], dtype=float32),
#   'probabilities': array([0.8527636, 0.1472364], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([1.0975465], dtype=float32),
#   'logistic': array([0.7498001], dtype=float32),
#   'probabilities': array([0.2501999 , 0.74980015], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.3504317], dtype=float32),
#   'logistic': array([0.20579982], dtype=float32),
#   'probabilities': array([0.79420024, 0.2057998 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.04635406], dtype=float32),
#   'logistic': array([0.5115864], dtype=float32),
#   'probabilities': array([0.48841357, 0.5115865 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.7276268], dtype=float32),
#   'logistic': array([0.1508914], dtype=float32),
#   'probabilities': array([0.84910864, 0.1508914 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.775457], dtype=float32),
#   'logistic': array([0.68470013], dtype=float32),
#   'probabilities': array([0.3152998 , 0.68470013], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.69155025], dtype=float32),
#   'logistic': array([0.33368832], dtype=float32),
#   'probabilities': array([0.6663117, 0.3336883], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.4635901], dtype=float32),
#   'logistic': array([0.18791883], dtype=float32),
#   'probabilities': array([0.8120811 , 0.18791883], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.52858865], dtype=float32),
#   'logistic': array([0.37084615], dtype=float32),
#   'probabilities': array([0.62915385, 0.37084612], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.68173325], dtype=float32),
#   'logistic': array([0.33587456], dtype=float32),
#   'probabilities': array([0.66412544, 0.33587456], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.6843783], dtype=float32),
#   'logistic': array([0.15651658], dtype=float32),
#   'probabilities': array([0.84348345, 0.15651657], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.92364645], dtype=float32),
#   'logistic': array([0.7157845], dtype=float32),
#   'probabilities': array([0.28421548, 0.7157845 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.5000188], dtype=float32),
#   'logistic': array([0.18242273], dtype=float32),
#   'probabilities': array([0.8175773 , 0.18242273], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.6316075], dtype=float32),
#   'logistic': array([0.16361028], dtype=float32),
#   'probabilities': array([0.8363898 , 0.16361026], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.9430361], dtype=float32),
#   'logistic': array([0.2802875], dtype=float32),
#   'probabilities': array([0.71971256, 0.28028747], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.15773642], dtype=float32),
#   'logistic': array([0.46064746], dtype=float32),
#   'probabilities': array([0.53935254, 0.46064743], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.94520396], dtype=float32),
#   'logistic': array([0.27985036], dtype=float32),
#   'probabilities': array([0.72014964, 0.27985033], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-2.0236382], dtype=float32),
#   'logistic': array([0.1167433], dtype=float32),
#   'probabilities': array([0.88325673, 0.11674331], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([1.7022072], dtype=float32),
#   'logistic': array([0.8458228], dtype=float32),
#   'probabilities': array([0.1541772 , 0.84582275], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.78210163], dtype=float32),
#   'logistic': array([0.6861329], dtype=float32),
#   'probabilities': array([0.31386712, 0.6861329 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.1484009], dtype=float32),
#   'logistic': array([0.5370323], dtype=float32),
#   'probabilities': array([0.46296772, 0.5370323 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([1.0017525], dtype=float32),
#   'logistic': array([0.731403], dtype=float32),
#   'probabilities': array([0.268597, 0.731403], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-2.097937], dtype=float32),
#   'logistic': array([0.10929745], dtype=float32),
#   'probabilities': array([0.89070255, 0.10929748], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.7814617], dtype=float32),
#   'logistic': array([0.14412272], dtype=float32),
#   'probabilities': array([0.8558773 , 0.14412275], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.3469025], dtype=float32),
#   'logistic': array([0.20637724], dtype=float32),
#   'probabilities': array([0.79362273, 0.20637724], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.7253554], dtype=float32),
#   'logistic': array([0.3262148], dtype=float32),
#   'probabilities': array([0.6737852, 0.3262148], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.5282651], dtype=float32),
#   'logistic': array([0.37092164], dtype=float32),
#   'probabilities': array([0.6290784, 0.3709216], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.33428693], dtype=float32),
#   'logistic': array([0.5828021], dtype=float32),
#   'probabilities': array([0.4171979, 0.5828021], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.2813145], dtype=float32),
#   'logistic': array([0.56986845], dtype=float32),
#   'probabilities': array([0.43013152, 0.56986845], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.4101088], dtype=float32),
#   'logistic': array([0.39888605], dtype=float32),
#   'probabilities': array([0.601114  , 0.39888602], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.46415037], dtype=float32),
#   'logistic': array([0.3860017], dtype=float32),
#   'probabilities': array([0.6139983 , 0.38600168], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.6213034], dtype=float32),
#   'logistic': array([0.3494851], dtype=float32),
#   'probabilities': array([0.6505149 , 0.34948507], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.5066739], dtype=float32),
#   'logistic': array([0.18143222], dtype=float32),
#   'probabilities': array([0.81856775, 0.18143223], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.57987094], dtype=float32),
#   'logistic': array([0.6410377], dtype=float32),
#   'probabilities': array([0.3589623, 0.6410377], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.9415405], dtype=float32),
#   'logistic': array([0.12547868], dtype=float32),
#   'probabilities': array([0.8745213 , 0.12547871], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.0337446], dtype=float32),
#   'logistic': array([0.26235878], dtype=float32),
#   'probabilities': array([0.7376412 , 0.26235878], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.23187315], dtype=float32),
#   'logistic': array([0.55770993], dtype=float32),
#   'probabilities': array([0.44229   , 0.55770993], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.5611199], dtype=float32),
#   'logistic': array([0.36328837], dtype=float32),
#   'probabilities': array([0.6367116 , 0.36328834], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.4795673], dtype=float32),
#   'logistic': array([0.18549275], dtype=float32),
#   'probabilities': array([0.8145072 , 0.18549278], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.9558074], dtype=float32),
#   'logistic': array([0.27771842], dtype=float32),
#   'probabilities': array([0.7222816 , 0.27771842], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.02809], dtype=float32),
#   'logistic': array([0.2634546], dtype=float32),
#   'probabilities': array([0.73654544, 0.26345456], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.851023], dtype=float32),
#   'logistic': array([0.13575283], dtype=float32),
#   'probabilities': array([0.8642472 , 0.13575283], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.4854524], dtype=float32),
#   'logistic': array([0.1846053], dtype=float32),
#   'probabilities': array([0.8153947 , 0.18460529], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.33871925], dtype=float32),
#   'logistic': array([0.58387935], dtype=float32),
#   'probabilities': array([0.41612062, 0.5838794 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.83125055], dtype=float32),
#   'logistic': array([0.6966193], dtype=float32),
#   'probabilities': array([0.3033807, 0.6966193], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.5661452], dtype=float32),
#   'logistic': array([0.6378732], dtype=float32),
#   'probabilities': array([0.36212677, 0.63787323], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.892553], dtype=float32),
#   'logistic': array([0.70941675], dtype=float32),
#   'probabilities': array([0.29058325, 0.70941675], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.14046884], dtype=float32),
#   'logistic': array([0.46494046], dtype=float32),
#   'probabilities': array([0.5350596 , 0.46494043], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.79942316], dtype=float32),
#   'logistic': array([0.31014895], dtype=float32),
#   'probabilities': array([0.6898511 , 0.31014892], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.12129235], dtype=float32),
#   'logistic': array([0.53028595], dtype=float32),
#   'probabilities': array([0.46971405, 0.53028595], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.5516918], dtype=float32),
#   'logistic': array([0.17484206], dtype=float32),
#   'probabilities': array([0.825158  , 0.17484206], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.781199], dtype=float32),
#   'logistic': array([0.14415511], dtype=float32),
#   'probabilities': array([0.85584486, 0.14415514], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.5354311], dtype=float32),
#   'logistic': array([0.1772004], dtype=float32),
#   'probabilities': array([0.82279956, 0.17720044], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.08932149], dtype=float32),
#   'logistic': array([0.52231556], dtype=float32),
#   'probabilities': array([0.4776845 , 0.52231556], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-2.7740836], dtype=float32),
#   'logistic': array([0.05874079], dtype=float32),
#   'probabilities': array([0.94125915, 0.05874082], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.96862733], dtype=float32),
#   'logistic': array([0.27515417], dtype=float32),
#   'probabilities': array([0.7248458 , 0.27515417], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.6651672], dtype=float32),
#   'logistic': array([0.15906958], dtype=float32),
#   'probabilities': array([0.8409304 , 0.15906957], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.979794], dtype=float32),
#   'logistic': array([0.27293265], dtype=float32),
#   'probabilities': array([0.72706735, 0.27293265], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.1731378], dtype=float32),
#   'logistic': array([0.23628831], dtype=float32),
#   'probabilities': array([0.7637117 , 0.23628828], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.9701524], dtype=float32),
#   'logistic': array([0.27485013], dtype=float32),
#   'probabilities': array([0.72514987, 0.27485013], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([1.2204877], dtype=float32),
#   'logistic': array([0.7721493], dtype=float32),
#   'probabilities': array([0.22785065, 0.7721494 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.5404972], dtype=float32),
#   'logistic': array([0.17646301], dtype=float32),
#   'probabilities': array([0.823537  , 0.17646301], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.9454541], dtype=float32),
#   'logistic': array([0.12504986], dtype=float32),
#   'probabilities': array([0.8749501 , 0.12504989], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.36622941], dtype=float32),
#   'logistic': array([0.59054756], dtype=float32),
#   'probabilities': array([0.40945244, 0.59054756], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.08122671], dtype=float32),
#   'logistic': array([0.47970447], dtype=float32),
#   'probabilities': array([0.5202955 , 0.47970447], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([1.7325739], dtype=float32),
#   'logistic': array([0.84974134], dtype=float32),
#   'probabilities': array([0.15025865, 0.84974134], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.5840361], dtype=float32),
#   'logistic': array([0.64199555], dtype=float32),
#   'probabilities': array([0.3580044 , 0.64199555], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.9351676], dtype=float32),
#   'logistic': array([0.12617971], dtype=float32),
#   'probabilities': array([0.87382025, 0.12617971], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.6014174], dtype=float32),
#   'logistic': array([0.6459805], dtype=float32),
#   'probabilities': array([0.3540195 , 0.64598054], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.19399083], dtype=float32),
#   'logistic': array([0.54834616], dtype=float32),
#   'probabilities': array([0.4516538, 0.5483462], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([1.3023664], dtype=float32),
#   'logistic': array([0.78623295], dtype=float32),
#   'probabilities': array([0.21376704, 0.78623295], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.2362584], dtype=float32),
#   'logistic': array([0.22508794], dtype=float32),
#   'probabilities': array([0.7749121 , 0.22508794], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.5815575], dtype=float32),
#   'logistic': array([0.17057502], dtype=float32),
#   'probabilities': array([0.82942504, 0.17057501], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.26768315], dtype=float32),
#   'logistic': array([0.566524], dtype=float32),
#   'probabilities': array([0.43347597, 0.566524  ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.7329588], dtype=float32),
#   'logistic': array([0.15020949], dtype=float32),
#   'probabilities': array([0.84979045, 0.1502095 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([1.2884191], dtype=float32),
#   'logistic': array([0.7838795], dtype=float32),
#   'probabilities': array([0.21612051, 0.7838795 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.0775789], dtype=float32),
#   'logistic': array([0.519385], dtype=float32),
#   'probabilities': array([0.480615, 0.519385], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-1.5443029], dtype=float32),
#   'logistic': array([0.17591064], dtype=float32),
#   'probabilities': array([0.8240894 , 0.17591062], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.25748742], dtype=float32),
#   'logistic': array([0.56401855], dtype=float32),
#   'probabilities': array([0.43598145, 0.56401855], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.03957689], dtype=float32),
#   'logistic': array([0.49010706], dtype=float32),
#   'probabilities': array([0.50989294, 0.49010706], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-2.1465197], dtype=float32),
#   'logistic': array([0.1046569], dtype=float32),
#   'probabilities': array([0.89534307, 0.10465688], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([0.06397665], dtype=float32),
#   'logistic': array([0.5159887], dtype=float32),
#   'probabilities': array([0.4840113, 0.5159887], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([0.4253844], dtype=float32),
#   'logistic': array([0.60477096], dtype=float32),
#   'probabilities': array([0.39522904, 0.604771  ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([1.1270689], dtype=float32),
#   'logistic': array([0.75529754], dtype=float32),
#   'probabilities': array([0.24470243, 0.75529754], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([1.4876002], dtype=float32),
#   'logistic': array([0.8157178], dtype=float32),
#   'probabilities': array([0.18428218, 0.8157178 ], dtype=float32),
#   'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object)},
#  {'logits': array([-0.20685816], dtype=float32),
#   'logistic': array([0.44846907], dtype=float32),
#   'probabilities': array([0.55153096, 0.4484691 ], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.6758802], dtype=float32),
#   'logistic': array([0.15764177], dtype=float32),
#   'probabilities': array([0.8423583 , 0.15764178], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-2.335915], dtype=float32),
#   'logistic': array([0.08819184], dtype=float32),
#   'probabilities': array([0.9118082 , 0.08819185], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-2.116057], dtype=float32),
#   'logistic': array([0.10754594], dtype=float32),
#   'probabilities': array([0.8924541 , 0.10754595], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-1.0869579], dtype=float32),
#   'logistic': array([0.25219157], dtype=float32),
#   'probabilities': array([0.74780846, 0.25219154], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.7122317], dtype=float32),
#   'logistic': array([0.3291059], dtype=float32),
#   'probabilities': array([0.6708941, 0.3291059], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)},
#  {'logits': array([-0.998894], dtype=float32),
#   'logistic': array([0.26915896], dtype=float32),
#   'probabilities': array([0.73084104, 0.26915893], dtype=float32),
#   'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object)}]

# %% [markdown]
# # DNN Classifier

# %%
dnn_model = tf.estimator.DNNClassifier(hidden_units=[10,10,10],feature_columns=feat_cols,n_classes=2)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\USER\AppData\Local\Temp\tmpbl_t1dqr
# INFO:tensorflow:Using config: {'_model_dir': 'C:\\Users\\USER\\AppData\\Local\\Temp\\tmpbl_t1dqr', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x000001F04D7E8408>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
# UH OH! AN ERROR. Check out the video to see why and how to fix.
# https://github.com/tensorflow/tensorflow/blob/master/tensorflow/python/feature_column/feature_column.py
dnn_model.train(input_fn=input_func,steps=1000)

# %%
embedded_group_column = tf.feature_column.embedding_column(assigned_group, dimension=4)

# %%
feat_cols = [num_preg ,plasma_gluc,dias_press ,tricep ,insulin,bmi,diabetes_pedigree ,embedded_group_column, age_buckets]

# %%
input_func = tf.estimator.inputs.pandas_input_fn(x=X_train,y=y_train,batch_size=10,num_epochs=1000,shuffle=True)

# %%
dnn_model = tf.estimator.DNNClassifier(hidden_units=[10,10,10],feature_columns=feat_cols,n_classes=2)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\USER\AppData\Local\Temp\tmpscsqiwii
# INFO:tensorflow:Using config: {'_model_dir': 'C:\\Users\\USER\\AppData\\Local\\Temp\\tmpscsqiwii', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x000001F04DF30F88>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
dnn_model.train(input_fn=input_func,steps=1000)
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:From c:\users\user\anaconda3\envs\yienv\lib\site-packages\tensorflow\python\feature_column\feature_column_v2.py:2997: VocabularyListCategoricalColumn._num_buckets (from tensorflow.python.feature_column.feature_column_v2) is deprecated and will be removed after 2018-11-30.
# Instructions for updating:
# The old _FeatureColumn APIs are being deprecated. Please use the new FeatureColumn APIs instead.
# WARNING:tensorflow:From c:\users\user\anaconda3\envs\yienv\lib\site-packages\tensorflow\python\ops\array_grad.py:425: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into C:\Users\USER\AppData\Local\Temp\tmpscsqiwii\model.ckpt.
# INFO:tensorflow:loss = 6.5455465, step = 0
# INFO:tensorflow:global_step/sec: 232.337
# INFO:tensorflow:loss = 7.1355996, step = 100 (0.445 sec)
# INFO:tensorflow:global_step/sec: 302.361
# INFO:tensorflow:loss = 6.748086, step = 200 (0.315 sec)
# INFO:tensorflow:global_step/sec: 278.624
# INFO:tensorflow:loss = 6.186408, step = 300 (0.359 sec)
# INFO:tensorflow:global_step/sec: 301.273
# INFO:tensorflow:loss = 8.668088, step = 400 (0.334 sec)
# INFO:tensorflow:global_step/sec: 302.01
# INFO:tensorflow:loss = 3.9839182, step = 500 (0.331 sec)
# INFO:tensorflow:global_step/sec: 288.124
# INFO:tensorflow:loss = 4.4813633, step = 600 (0.347 sec)
# INFO:tensorflow:global_step/sec: 309.466
# INFO:tensorflow:loss = 3.8165417, step = 700 (0.323 sec)
# INFO:tensorflow:global_step/sec: 310.424
# INFO:tensorflow:loss = 4.602338, step = 800 (0.322 sec)
# INFO:tensorflow:global_step/sec: 287.299
# INFO:tensorflow:loss = 3.0317125, step = 900 (0.348 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into C:\Users\USER\AppData\Local\Temp\tmpscsqiwii\model.ckpt.
# INFO:tensorflow:Loss for final step: 6.3759108.

# %%
eval_input_func = tf.estimator.inputs.pandas_input_fn(
      x=X_test,
      y=y_test,
      batch_size=10,
      num_epochs=1,
      shuffle=False)

# %%
dnn_model.evaluate(eval_input_func)

# %% [markdown]
# # Great Job!
